# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [4,5,6]

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.plot([33,38,99],[144,676,550])
plt.show()

# %%
plt.scatter([33,38,99],[144,676,550])
plt.show()

# %%
plt.plot([33,38,99],[144,676,550])
plt.scatter([33,38,99],[144,676,550])
plt.show()

# %%
plt.xlabel("Time")
plt.ylabel("Distance")

plt.plot([33,38,99],[144,676,550], label = "First Line",color='red')
plt.scatter([33,38,99],[144,676,550], label = "Dots", color='blue')

plt.legend()

plt.show()
